# %%
import pandas as pd

# %%
reports_file_path = 'data/br/firefox/firefox.csv'
relations_file_path = 'data/br/firefox/firefox_pairs.csv'

reports_firefox = pd.read_csv(reports_file_path, index_col='bug_id')
relations_firefox = pd.read_csv(relations_file_path)

# %%
reports_firefox.head()
# Out:
#        priority    component  dup_id  \
# bug_id
# 10954        P3  Preferences      []
# 14871        --      General  269442
# 19118        --  Preferences      []
# 54746        P3  Preferences      []
# 56892        P3      General      []
#
#                                                short_desc  \
# bug_id
# 10954      Dialup properties needs to be exposed in prefs
# 14871                         [Find] Find whole word only
# 19118   Plug-In Manager (ui for choosing mimetype-plug...
# 54746   Language encodings in font prefs dialog not so...
# 56892            Synaptics touchpad scrolling not working
#
#                                               description bug_status  \
# bug_id
# 10954   The dialup properties of the profile should be...   RESOLVED
# 14871   Please add Match Whole Word Only option to bro...   RESOLVED
# 19118   I would really like a plug-in manager for my b...   RESOLVED
# 54746   Language encodings are listed in a seemingly r...   RESOLVED
# ...

# %%
relations_firefox.head()
# Out:
#    issue_id                                          duplicate
# 0     10954                                                NaN
# 1     14871                 243500;410103;505684;515027;528678
# 2     19118   326494;328227;414070;436576;443686;457861;475975
# 3     54746                                                NaN
# 4     56892  191258;281233;290692;300719;307581;310641;3117...

# %%
len(reports_firefox)
# Out:
# 115814

# %%
reports_file_path = 'data/br/openoffice/openoffice.csv'
relations_file_path = 'data/br/openoffice/openoffice_pairs.csv'

reports_openoffice = pd.read_csv(reports_file_path, index_col='bug_id')
relations_openoffice = pd.read_csv(relations_file_path)

# %%
reports_openoffice.head()
# Out:
#        bug_severity bug_status  \
# bug_id
# 13          trivial     CLOSED
# 14          trivial     CLOSED
# 15          trivial     CLOSED
# 16          trivial     CLOSED
# 17          trivial     CLOSED
#
#                                                 component  \
# bug_id
# 13                                                   code
# 14                                 Website general issues
# 15                                               Bugzilla
# 16      _openoffice.org administrative interface (obso...
# 17                         _openoffice.org CVS (obsolete)
#
#                       creation_ts                   delta_ts  \
# bug_id
# 13      2000-10-16 18:33:00 +0000  2003-12-06 14:52:32 +0000
# 14      2000-10-17 19:40:00 +0000  2006-02-07 22:23:55 +0000
# 15      2000-10-19 11:49:00 +0000  2003-12-27 10:23:17 +0000
# 16      2000-10-20 15:06:00 +0000  2003-12-06 14:52:32 +0000
# 17      2000-10-20 18:46:00 +0000  2003-12-06 14:52:32 +0000
#
# ...

# %%
relations_openoffice.head()
# Out:
#    issue_id                                          duplicate
# 0     51549  52538;51703;51446;51937;51488;51722;51704;5145...
# 1     37805    37411;36327;37026;37521;37706;37663;36862;37707
# 2     88488         54568;35616;111788;79244;51118;59483;63653
# 3       495                                                NaN
# 4     17628  21822;6259;20644;19045;19420;23937;34990;6036;...

# %%
len(reports_openoffice)
# Out:
# 98070

# %%
reports_file_path = 'data/br/eclipse/eclipse.csv'
relations_file_path = 'data/br/eclipse/eclipse_pairs.csv'

reports_eclipse = pd.read_csv(reports_file_path, index_col='bug_id')
relations_eclipse = pd.read_csv(relations_file_path)

# %%
len(reports_eclipse)
# Out:
# 361006

# %%
reports_eclipse.head()
# Out:
#        bug_severity bug_status component                creation_ts  \
# bug_id
# 3            normal   RESOLVED      Team  2001-10-10 21:34:00 -0400
# 1            normal     CLOSED      Team  2001-10-10 21:34:00 -0400
# 8            normal   RESOLVED      Team  2001-10-10 21:34:00 -0400
# 4            normal   RESOLVED      Team  2001-10-10 21:34:00 -0400
# 6            normal   RESOLVED      Team  2001-10-10 21:34:00 -0400
#
#                          delta_ts  \
# bug_id
# 3       2010-05-07 10:28:53 -0400
# 1       2012-02-09 15:57:47 -0500
# 8       2011-05-17 11:40:32 -0400
# 4       2002-03-01 16:27:31 -0500
# 6       2002-02-07 16:29:37 -0500
#
#                                               description dup_id priority  \
# bug_id
# 3       KM (10/2/2001 5:55:18 PM)\n\tThis PR about the...     []       P5
# 1       - Setup a project that contains a *.gif resour...     []       P3
# 8       With the current VCM API, a repository adapter...     []       P3
# ...

# %%
relations_eclipse.head(5)
# Out:
#    issue_id duplicate
# 0    214301    214611
# 1    214623       NaN
# 2    214445    214451
# 3    214466    214452
# 4    214181       NaN

# %%
relations_eclipse[relations_eclipse['duplicate'].str.contains('214825') == True]
# Out:
# Empty DataFrame
# Columns: [issue_id, duplicate]
# Index: []

# %%
reports_eclipse.loc[214825]
# Out:
# bug_severity                                               normal
# bug_status                                               RESOLVED
# component                                             GMF-runtime
# creation_ts                             2008-01-09 17:03:00 -0500
# delta_ts                                2010-07-19 21:59:45 -0400
# description     A model had been corrupted so that two semanti...
# dup_id                                                         []
# priority                                                       P3
# product                                                       GMP
# resolution                                                  FIXED
# short_desc                Loading model aborts on non-fatal error
# version                                                     2.0.1
# Name: 214825, dtype: object

# %%
reports_eclipse.loc[214623]
# Out:
# bug_severity                                               normal
# bug_status                                                 CLOSED
# component                                                  wst.ws
# creation_ts                             2008-01-08 10:40:00 -0500
# delta_ts                                2008-10-27 14:34:29 -0400
# description     1. Move the service slider to TEST when creati...
# dup_id                                                         []
# priority                                                       P3
# product                                           WTP Webservices
# resolution                                                WONTFIX
# short_desc      WSE hangs in external browser after invoking f...
# version                                                       3.0
# Name: 214623, dtype: object
